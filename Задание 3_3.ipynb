# %%
list = ['G','E','O','R','G','I']
list
# Out:
# ['G', 'E', 'O', 'R', 'G', 'I']

# %%
my_list = []


my_list = list.copy()
my_list
# Out:
# ['G', 'E', 'O', 'R', 'G', 'I']

# %%
my_list.sort()
my_list
# Out:
# ['E', 'G', 'G', 'I', 'O', 'R']

# %%
list1 = my_list.copy()
list1.extend(list)
list1
# Out:
# ['E', 'G', 'G', 'I', 'O', 'R', 'G', 'E', 'O', 'R', 'G', 'I']

# %%
list1.pop(0)
list1.pop(1)
list1.pop(2)
list1
# Out:
# ['G', 'I', 'R', 'G', 'E', 'O', 'R', 'G', 'I']

# %%
list
# Out:
# ['G', 'E', 'O', 'R', 'G', 'I']

# %%
my_list
# Out:
# ['E', 'G', 'G', 'I', 'O', 'R']

# %%
list1
# Out:
# ['G', 'I', 'R', 'G', 'E', 'O', 'R', 'G', 'I']
